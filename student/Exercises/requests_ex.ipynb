# %% [raw]
# ---
# title: "مسألة سحب البيانات"
# og:title: requests_ex
# toc: true
# format:
#   html: default
#   ipynb: default
# ---

# %% [markdown]
# في هذا التمرين ستتعلّم إرسال طلبات HTTP عبر الإنترنت باستعمال مكتبة `requests`، ثم تطبّق ذلك على واجهة برمجية تختارها بنفسك. اقرأ الأقسام بالترتيب، شغّل الخلايا واقرأ المخرجات، ثم انتقل إلى المسألة في القسم الأخير.

# %% [markdown]
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HassanAlgoz/python/blob/main/book/exercises/requests_ex.ipynb)

# %% [markdown]
# أضِف المكتبة إلى بيئتك (مثلاً بـ `uv add requests` أو `pip install requests`)، ثم استوردها في الخلية التالية.

# %%
#uv add requests

# %%
import requests

# %% [markdown]
# ## 1. مثال: PoetryDB
#
# في هذا القسم طلب بسيط إلى خدمة شِعر جاهزة؛ شغّل الخلايا وتابع كيف تتحوّل الاستجابة إلى بيانات بايثون (`json`).

# %%
response = requests.get("https://poetrydb.org/author/Emily Dickinson/title")

# %%
data = response.json()
print(data)
# Out:
# [{'title': 'Not at Home to Callers'}, {'title': 'Defrauded I a Butterfly --'}, {'title': 'The words the happy say'}, {'title': 'Summer begins to have the look'}, {'title': 'The Life we have is very great.'}, {'title': 'Could Hope inspect her Basis'}, {'title': 'Success is counted sweetest'}, {'title': 'I Years had been from Home'}, {'title': 'Musicians wrestle everywhere'}, {'title': 'Where Thou art -- that -- is Home --'}, {'title': 'The name -- of it -- is "Autumn" --'}, {'title': 'A Wind that rose'}, {'title': 'No Romance sold unto'}, {'title': "How know it from a Summer's Day?"}, {'title': 'Remorse -- is Memory -- awake --'}, {'title': 'There is a flower that Bees prefer'}, {'title': 'Twice had Summer her fair Verdure'}, {'title': 'One Year ago -- jots what?'}, {'title': "We thirst at first -- 'tis Nature's Act --"}, {'title': "She's happy, with a new Content --"}, {'title': 'The One who could repeat the Summer day'}, {'title': 'I many times thought Peace had come'}, {'title': 'So much of Heaven has gone from Earth'}, {'title': 'The Fact that Earth is Heaven --'}, {'title': 'So much Summer'}, {'title': 'Her sovereign People'}, {'title': 'Of Life to own --'}, {'title': 'When Memory is full'}, {'title': 'A Wife -- at daybreak I shall be'}, {'title': 'The stem of a departed Flower'}, {'title': 'Whatever it is -- she has tried it --'}, {'title': 'Oh Future! thou secreted peace'}, {'title': 'Said Death to Passion'}, {'title': 'I think that the Root of the Wind is Water --'}, {'title': 'Pain -- has an Element of Blank --'}, {'title': 'It can\'t be "Summer"!'}, {'title': '"Hope" is the thing with feathers'}, {'title': 'The Butterfly upon the Sky,'}, {'title': 'Summer for thee, grant I may be'}, {'title': 'Pain -- expands the Time --'}, {'title': 'Who were "the Father and the Son"'}, {'title': 'Growth of Man -- like Growth of Nature --'}, {'title': 'Death is a Dialogue between'}, {'title': 'A Door just opened on a street --'}, {'title': 'Summer -- we all have seen --'}, {'title': 'The good Will of a Flower'}, {'title': 'Each Life Converges to some Centre --'}, {'title': 'To her derided Home'}, {'title': 'One Day is there of the Series'}, {'title': 'The Veins of other Flowers'}, {'title': 'I know of people in the Grave'}, {'title': 'We should not mind so small a flower'}, {'title': 'I prayed, at first, a little Girl,'}, {'title': 'I never felt at Home -- Below'}, {'title': 'How much the present moment means'}, {'title': 'Now I knew I lost her --'}, {'title': 'Snow beneath whose chilly softness'}, {'title': "Floss won't save you from an Abyss"}, {'title': '"Arcturus" is his other name'}, {'title': 'Witchcraft was hung, in History,'}, {'title': 'Their Height in Heaven comforts not --'}, {'title': '"Faith" is a fine invention'}, {'title': 'Through the Dark Sod -- as Education'}, {'title': 'Some, too fragile for winter winds'}, {'title': 'Pain has but one Acquaintance'}, {'title': 'How Human Nature dotes'}, {'title': 'The Mountain sat upon the Plain'}, {'title': 'Just so -- Jesus -- raps'}, {'title': 'Rearrange a "Wife\'s" affection!'}, {'title': 'Water makes many Beds'}, {'title': 'In this short Life'}, {'title': 'Bereavement in their death to feel'}, {'title': 'Birthday of but a single pang'}, {'title': 'How the Waters closed above Him'}, {'title': "Tho' I get home how late -- how late"}, {'title': 'Which is best?  Heaven --'}, {'title': 'Lad of Athens, faithful be'}, {'title': 'If pain for peace prepares'}, {'title': 'Her spirit rose to such a height'}, {'title': 'Further in Summer than the Birds'}, {'title': 'Estranged from Beauty -- none can be --'}, {'title': 'Heaven is so far of the Mind'}, {'title': '"Lethe" in my flower,'}, {'title': 'How happy is the little Stone'}, {'title': 'What shall I do when the Summer troubles --'}, {'title': 'I know a place where Summer strives'}, {'title': 'A Tooth upon Our Peace'}, {'title': 'Like Rain it sounded till it curved'}, {'title': 'I rose -- because He sank --'}, {'title': 'Angels, in the  ...

# %%
response = requests.get("https://poetrydb.org/author,title/Shakespeare;Sonnet")
data = response.json()
print(data)

# %% [markdown]
# ## 2. مثال: تنزيل ملفات من GitHub

# %% [markdown]
# يلزمنا GitHub لتحميل الملفات بالنمط التالي:
#
# - إن كنا نتصفح الملف على هذا المسار: `https://github.com/HassanAlgoz/python/blob/main/book/datasets/students.csv`
# - فوجب تنزيله عبر هذا المسار: `https://raw.githubusercontent.com/HassanAlgoz/python/main/book/datasets/students.csv`

# %% [markdown]
# في المثال التالي نعرّف دالة تحوّل رابط صفحة GitHub (عرض المتصفّح) إلى رابط **raw** مناسب للتنزيل. نفّذ الخلايا واقرأ المسارات التي تطبعها الدالة.

# %%
from urllib.parse import urlparse

def github_convert_url(url: str) -> str:
    parsed = urlparse(url)
    if "githubusercontent" in parsed.hostname:
        return url
    x = parsed.path.lstrip("https://github.com/")
    x = x.replace("/blob", "")
    print(x)
    x = "https://raw.githubusercontent.com/" + x
    return x

# %% [markdown]
# ثم نعرّف دالة ترسل الطلب بعد تحويل الرابط إلى صيغة `raw` المناسبة:

# %%
def github_request_file(url: str):
    x = github_convert_url(url)
    return requests.get(x)

# %%
response1 = github_request_file(
    url="https://github.com/HassanAlgoz/python/blob/main/book/datasets/students.csv"
)

# %%
print(response1.text)

# %% [markdown]
# ونفس النتيجة لو جربنا بالرابط المباشر للتنزيل، لأننا تعاملنا مع هذه الحالة:

# %%
response2 = github_request_file(
    url="https://raw.githubusercontent.com/HassanAlgoz/python/main/book/datasets/students.csv"
)

# %%
print(response2.text)

# %% [markdown]
# ## 3. مثال: طلب صور من موقع القطط
#
# هنا نطلب JSON يصف صورة عشوائية؛ يمكن تشغيل المثال بدون مفتاح ضمن حدود الخدمة، أو تعيين المتغير البيئي `CAT_API_KEY` إن وفّرت مفتاحًا من الموقع.

# %%
import os

# الطلب يعمل بدون مفتاح ضمن حدود معيّنة؛ إن رغبت بمفتاح مجاني راجع https://thecatapi.com/
headers = {}
if key := os.environ.get("CAT_API_KEY"):
    headers["x-api-key"] = key

response = requests.get(
    url="https://api.thecatapi.com/v1/images/search",
    headers=headers,
)

# %%
print(response.text)

# %%
data = response.json()
data[0]["url"]

# %%
from IPython.display import Image, display

# display(Image(url=data[0]["url"]))

# %% [markdown]
# ## 4. المسألة: التطبيق على إحدى الواجهات البرمجية
#
# اختر واجهة برمجية واحدة وحقّق بها **مهمة واحدة** واضحة (مثلاً: جلب بيانات، أو بحث، أو صورة). في موقع المزوّد ابحث عن **API Documentation** أو **Developers** أو **Quick Start**؛ هناك تجد **نقاط الالتقاء** (Endpoints) والمعاملات المطلوبة.
#
# **استعمل إحدى الواجهات التالية** (أو واجهة أخرى بموافقة المدرّس):
#
# - [website screenshot | abstractapi](https://www.abstractapi.com/api/website-screenshot-api)
# - [poetrydb](https://poetrydb.org/index.html)
# - [newtown](https://newton.vercel.app/)
# - [alquran-cloud](https://alquran.cloud/api)
# - [Wikipedia](https://pypi.org/project/Wikipedia-API/)
# - [nasa](https://api.nasa.gov/)
# - [arxiv](https://info.arxiv.org/help/api/user-manual.html)
# - [Telegram](https://core.telegram.org/)
# - [Discord](https://discord.com/developers/docs/intro)
#
# قائمة أوسع (قد يتعطّل بعضها): [public-apis](https://github.com/public-apis/public-apis).
#
# للبحث عن فكرة: اكتب في محرك البحث ما تريد إنجازه + `API`؛ مثلاً `Google Maps API`.
#
# **ملاحظة:** قد تحتاج تسجيلًا للحصول على مفتاح، أو رصيدًا مدفوعًا — كل ذلك يُبيّن في مرجع المزوّد.

# %%
# طلباتك إلى الواجهة التي اخترتها، ثم معالجة الاستجابة (json() أو .text)
pass  # اكتب هنا
